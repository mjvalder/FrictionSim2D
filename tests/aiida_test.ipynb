# %%
import numpy as np
import io
import textwrap
from aiida import load_profile
from aiida.common.extendeddicts import AttributeDict
from aiida.engine import submit
from aiida.orm import Bool, Code, Str, SinglefileData, load_code
from aiida.plugins import CalculationFactory, DataFactory
import requests

load_profile()
# Out:
# Profile<uuid='4bdabcc7b3e546fca72eab12b51b1616' name='presto'>

# %%
builder = CalculationFactory("lammps.raw").get_builder()
builder.code = load_code("lammps@localhost")
